# %%
import json
import sys
import os
from collections import defaultdict
import torch
from transformers import AutoModel, AutoTokenizer
from sklearn.cluster import KMeans
import numpy as np
import json



from sklearn.decomposition import PCA
from sklearn.metrics import accuracy_score
from matplotlib import pyplot as plt


sys.path.append(os.path.join('../pstal-etu/lib/'))
from conllulib import CoNLLUReader

# %%
with open("mapping.json", "r") as file:
    mapping = json.load(file)

with open("embeddings.json", "r") as file:
    data_train = json.load(file)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
tokenizer = AutoTokenizer.from_pretrained('almanach/camembert-base')
model = AutoModel.from_pretrained('almanach/camembert-base')

# %%
def dataloader_with_embeddings(file, mapping):
    """
    Charge un fichier CoNLLU, extrait les embeddings des mots associés à leurs classes,
    et enregistre les résultats dans une structure.
    """
    data = []
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)

    with open(file, 'r') as file:
        reader = CoNLLUReader(file)
        for sent in reader.readConllu():
            mots = [tok["form"] for tok in sent]
            labels = [tok["frsemcor:noun"] for tok in sent]


            token_obj = tokenizer(mots, is_split_into_words=True, return_tensors='pt').to(device)
            word_ids = token_obj.word_ids()

            with torch.no_grad():
                embeddings = model(**token_obj)["last_hidden_state"]
            for word_idx in range(len(mots)):
                token_indices = [i for i, w_id in enumerate(word_ids) if w_id == word_idx]
                if token_indices:
                    avg_embedding = embeddings[:, token_indices, :].mean(dim=1).squeeze(0).cpu().numpy()
                    data.append({
                        "word": mots[word_idx],
                        "embedding": avg_embedding.tolist(),
                        "class": mapping[labels[word_idx]]
                    })
    return data, mapping

# %%
import numpy as np
from sklearn.cluster import KMeans
from sklearn.metrics import classification_report
import json
import torch
from transformers import AutoTokenizer, AutoModel
# from conllulib import CoNLLUReader

# Charger le tokenizer et le modèle
model = AutoModel.from_pretrained('almanach/camembert-base')
tokenizer = AutoTokenizer.from_pretrained('almanach/camembert-base')
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

path = '.'
# Charger les embeddings d'entraînement et le mapping
with open("embeddings.json", "r") as file:
    train_data = json.load(file)

with open("mapping.json", "r") as file:
    mapping = json.load(file)

# Calculer l'embedding moyen de chaque classe
num_classes = len(mapping)
class_embeddings = {cls: [] for cls in range(num_classes)}

for item in train_data:
    class_embeddings[item["class"]].append(np.array(item["embedding"]))

class_means = {
    cls: np.mean(embeddings, axis=0) if embeddings else np.zeros_like(train_data[0]["embedding"])
    for cls, embeddings in class_embeddings.items()
}

# Fonction pour charger les données de test et leurs embeddings
def dataloader_test(file):
    test_data = []
    with open(file, 'r') as f:
        reader = CoNLLUReader(f)
        for sent in reader.readConllu():
            mots = [tok["form"] for tok in sent]
            labels = [tok.get("frsemcor:noun", "") for tok in sent]

            token_obj = tokenizer(mots, is_split_into_words=True, return_tensors='pt').to(device)
            word_ids = token_obj.word_ids()

            with torch.no_grad():
                embeddings = model(**token_obj)["last_hidden_state"]

            for word_idx in range(len(mots)):
                token_indices = [i for i, w_id in enumerate(word_ids) if w_id == word_idx]
                if token_indices:
                    avg_embedding = embeddings[:, token_indices, :].mean(dim=1).squeeze(0).cpu().numpy()
                    test_data.append({
                        "word": mots[word_idx],
                        "embedding": avg_embedding.tolist(),
                        "true_label": mapping.get(labels[word_idx], -1)
                    })
    return test_data

# Charger les données de test
file_test = os.path.join(path, '../pstal-etu/sequoia/sequoia-ud.parseme.frsemcor.simple.train')
test_data = dataloader_test(file_test)


from collections import defaultdict

# Appliquer KMeans aux données d'entraînement
kmeans = KMeans(n_clusters=num_classes, random_state=42)
train_embeddings = [item["embedding"] for item in train_data]
train_labels = [item["class"] for item in train_data]
kmeans.fit(train_embeddings)

# Créer une correspondance entre clusters et classes
cluster_to_class = {}
cluster_class_counts = defaultdict(lambda: defaultdict(int))

for i, label in enumerate(train_labels):
    cluster = kmeans.labels_[i]
    cluster_class_counts[cluster][label] += 1

for cluster, class_count in cluster_class_counts.items():
    cluster_to_class[cluster] = max(class_count, key=class_count.get)

# Prédiction pour les données de test
true_labels = []
predicted_labels = []

for item in test_data:
    embedding = np.array(item["embedding"])
    true_label = item["true_label"]
    cluster = kmeans.predict([embedding])[0]
    predicted_label = cluster_to_class.get(cluster, -1)

    true_labels.append(true_label)
    predicted_labels.append(predicted_label)

    # Afficher la phrase avec les prédictions
    print(f"Word: {item['word']}, True Label: {true_label}, Predicted Label: {predicted_label}")

# Calculer et afficher les statistiques
print("Classification Report:")
print(classification_report(true_labels, predicted_labels, zero_division=0))
# Out:
# Word: Gutenberg, True Label: 0, Predicted Label: 1
# Word: Cette, True Label: 1, Predicted Label: 1
# Word: exposition, True Label: 2, Predicted Label: 1
# Word: nous, True Label: 1, Predicted Label: 1
# Word: apprend, True Label: 1, Predicted Label: 1
# Word: que, True Label: 1, Predicted Label: 1
# Word: dès, True Label: 1, Predicted Label: 1
# Word: le, True Label: 1, Predicted Label: 1
# Word: XIIe, True Label: 1, Predicted Label: 1
# Word: siècle, True Label: 3, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: à, True Label: 1, Predicted Label: 1
# Word: Dammarie-sur-Saulx, True Label: 4, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: entre, True Label: 1, Predicted Label: 1
# Word: autres, True Label: 1, Predicted Label: 1
# Word: sites, True Label: 5, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: une, True Label: 1, Predicted Label: 1
# Word: industrie, True Label: 2, Predicted Label: 1
# Word: métallurgique, True Label: 1, Predicted Label: 1
# Word: existait, True Label: 1, Predicted Label: 1
# Word: ., True Label: 1, Predicted Label: 1
# Word: Ensuite, True Label: 1, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: fut, True Label: 1, Predicted Label: 1
# Word: installée, True Label: 1, Predicted Label: 1
# Word: une, True Label: 1, Predicted Label: 1
# Word: autre, True Label: 1, Predicted Label: 1
# Word: forge, True Label: 5, Predicted Label: 1
# Word: à, True Label: 1, Predicted Label: 1
# Word: la, True Label: 1, Predicted Label: 1
# Word: Vacquerie, True Label: 4, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: à, True Label: 1, Predicted Label: 1
# Word: l', True Label: 1, Predicted Label: 1
# Word: emplacement, True Label: 5, Predicted Label: 1
# Word: aujourd'hui, True Label: 1, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: Cora, True Label: 4, Predicted Label: 1
# Word: ., True Label: 1, Predicted Label: 1
# Word: En, True Label: 1, Predicted Label: 1
# Word: 1953, True Label: 3, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: les, True Label: 1, Predicted Label: 1
# Word: hauts, True Label: 1, Predicted Label: 1
# Word: fourneaux, True Label: 1, Predicted Label: 1
# Word: et, True Label: 1, Predicted Label: 1
# Word: fonderies, True Label: 4, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: Cousances, True Label: 4, Predicted Label: 1
# Word: virent, True Label: 1, Predicted Label: 1
# Word: le, True Label: 1, Predicted Label: 1
# Word: jour, True Label: 1, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: puis, True Label: 1, Predicted Label: 1
# Word: Jean, True Label: 1, Predicted Label: 1
# Word: Baudesson, True Label: 1, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: maire, True Label: 0, Predicted Label: 1
# Word: échevin, True Label: 0, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: Saint-Dizier, True Label: 4, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: autorisé, True Label: 1, Predicted Label: 1
# Word: par, True Label: 1, Predicted Label: 1
# Word: lettres, True Label: 1, Predicted Label: 1
# Word: patentes, True Label: 1, Predicted Label: 1
# Word: d', True Label: 1, Predicted Label: 1
# Word: Henri, True Label: 1, Predicted Label: 1
# Word: IV, True Label: 1, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: installa, True Label: 1, Predicted Label: 1
# Word: à, True Label: 1, Predicted Label: 1
# Word: Marnaval, True Label: 4, Predicted Label: 1
# Word: -, True Label: 1, Predicted Label: 1
# Word: qui, True Label: 1, Predicted Label: 1
# Word: signifiait, True Label: 1, Predicted Label: 1
# Word: val, True Label: 6, Predicted Label: 1
# Word: ou, True Label: 1, Predicted Label: 1
# Word: vallée, True Label: 6, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: la, True Label: 1, Predicted Label: 1
# Word: Marne, True Label: 4, Predicted Label: 1
# Word: ou, True Label: 1, Predicted Label: 1
# Word: bien, True Label: 1, Predicted Label: 1
# Word: en, True Label: 1, Predicted Label: 1
# Word: aval, True Label: 6, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: la, True Label: 1, Predicted Label: 1
# Word: Marne, True Label: 4, Predicted Label: 1
# Word: -, True Label: 1, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: une, True Label: 1, Predicted Label: 1
# Word: forge, True Label: 5, Predicted Label: 1
# Word: qui, True Label: 1, Predicted Label: 1
# Word: connut, True Label: 1, Predicted Label: 1
# Word: son, True Label: 1, Predicted Label: 1
# Word: apogée, True Label: 3, Predicted Label: 1
# Word: à, True Label: 1, Predicted Label: 1
# Word: le, True Label: 1, Predicted Label: 1
# Word: XIXe, True Label: 1, Predicted Label: 1
# Word: siècle, True Label: 3, Predicted Label: 1
# Word: ., True Label: 1, Predicted Label: 1
# Word: Tout, True Label: 1, Predicted Label: 1
# Word: à, True Label: 1, Predicted Label: 1
# Word: le, True Label: 1, Predicted Label: 1
# Word: long, True Label: 1, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: les, True Label: 1, Predicted Label: 1
# Word: années, True Label: 3, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: nouveaux, True Label: 1, Predicted Label: 1
# Word: sites, True Label: 5, Predicted Label: 1
# Word: furent, True Label: 1, Predicted Label: 1
# Word: créés, True Label: 1, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: notamment, True Label: 1, Predicted Label: 1
# Word: à, True Label: 1, Predicted Label: 1
# Word: Haironville, True Label: 4, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: puis, True Label: 1, Predicted Label: 1
# Word: plus, True Label: 1, Predicted Label: 1
# Word: tard, True Label: 1, Predicted Label: 1
# Word: à, True Label: 1, Predicted Label: 1
# Word: Ancerville, True Label: 4, Predicted Label: 1
# Word: ., True Label: 1, Predicted Label: 1
# Word: Amélioration, True Label: 2, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: la, True Label: 1, Predicted Label: 1
# Word: sécurité, True Label: 7, Predicted Label: 1
# Word: Le, True Label: 1, Predicted Label: 1
# Word: maire, True Label: 0, Predicted Label: 1
# Word: a, True Label: 1, Predicted Label: 1
# Word: invité, True Label: 1, Predicted Label: 1
# Word: les, True Label: 1, Predicted Label: 1
# Word: membres, True Label: 0, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: le, True Label: 1, Predicted Label: 1
# Word: conseil, True Label: 4, Predicted Label: 1
# Word: à, True Label: 1, Predicted Label: 1
# Word: élaborer, True Label: 1, Predicted Label: 1
# Word: le, True Label: 1, Predicted Label: 1
# Word: programme, True Label: 8, Predicted Label: 1
# Word: d', True Label: 1, Predicted Label: 1
# Word: amélioration, True Label: 2, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: la, True Label: 1, Predicted Label: 1
# Word: voirie, True Label: 5, Predicted Label: 1
# Word: communale, True Label: 1, Predicted Label: 1
# Word: et, True Label: 1, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: la, True Label: 1, Predicted Label: 1
# Word: sécurité, True Label: 1, Predicted Label: 1
# Word: routière, True Label: 1, Predicted Label: 1
# Word: pour, True Label: 1, Predicted Label: 1
# Word: l', True Label: 1, Predicted Label: 1
# Word: année, True Label: 3, Predicted Label: 1
# Word: 1999, True Label: 3, Predicted Label: 1
# Word: ., True Label: 1, Predicted Label: 1
# Word: Il, True Label: 1, Predicted Label: 1
# Word: a, True Label: 1, Predicted Label: 1
# Word: rappelé, True Label: 1, Predicted Label: 1
# Word: que, True Label: 1, Predicted Label: 1
# Word: plusieurs, True Label: 1, Predicted Label: 1
# Word: automobilistes, True Label: 0, Predicted Label: 1
# Word: ont, True Label: 1, Predicted Label: 1
# Word: quitté, True Label: 1, Predicted Label: 1
# Word: la, True Label: 1, Predicted Label: 1
# Word: chaussée, True Label: 5, Predicted Label: 1
# Word: à, True Label: 1, Predicted Label: 1
# Word: l', True Label: 1, Predicted Label: 1
# Word: intersection, True Label: 5, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: la, True Label: 1, Predicted Label: 1
# Word: RD192, True Label: 5, Predicted Label: 1
# Word: et, True Label: 1, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: le, True Label: 1, Predicted Label: 1
# Word: chemin, True Label: 5, Predicted Label: 1
# Word: rural, True Label: 1, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: la, True Label: 1, Predicted Label: 1
# Word: Vaux, True Label: 1, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: les, True Label: 1, Predicted Label: 1
# Word: Fossés, True Label: 1, Predicted Label: 1
# Word: et, True Label: 1, Predicted Label: 1
# Word: qu', True Label: 1, Predicted Label: 1
# Word: il, True Label: 1, Predicted Label: 1
# Word: convient, True Label: 1, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: modifier, True Label: 1, Predicted Label: 1
# Word: le, True Label: 1, Predicted Label: 1
# Word: régime, True Label: 8, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: priorité, True Label: 7, Predicted Label: 1
# Word: à, True Label: 1, Predicted Label: 1
# Word: cet, True Label: 1, Predicted Label: 1
# Word: endroit, True Label: 5, Predicted Label: 1
# Word: ., True Label: 1, Predicted Label: 1
# Word: Espoir, True Label: 9, Predicted Label: 1
# Word: Pourquoi, True Label: 1, Predicted Label: 1
# Word: ce, True Label: 1, Predicted Label: 1
# Word: thème, True Label: 8, Predicted Label: 1
# Word: ?, True Label: 1, Predicted Label: 1
# Word: ", True Label: 1, Predicted Label: 1
# Word: Tout, True Label: 1, Predicted Label: 1
# Word: simplement, True Label: 1, Predicted Label: 1
# Word: ", True Label: 1, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: a, True Label: 1, Predicted Label: 1
# Word: précisé, True Label: 1, Predicted Label: 1
# Word: Roger, True Label: 1, Predicted Label: 1
# Word: Thiriot, True Label: 1, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: ", True Label: 1, Predicted Label: 1
# Word: parce, True Label: 1, Predicted Label: 1
# Word: que, True Label: 1, Predicted Label: 1
# Word: l', True Label: 1, Predicted Label: 1
# Word: histoire, True Label: 8, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: le, True Label: 1, Predicted Label: 1
# Word: travail, True Label: 2, Predicted Label: 1
# Word: industriel, True Label: 1, Predicted Label: 1
# Word: est, True Label: 1, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: ici, True Label: 1, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: une, True Label: 1, Predicted Label: 1
# Word: longue, True Label: 1, Predicted Label: 1
# Word: et, True Label: 1, Predicted Label: 1
# Word: vieille, True Label: 1, Predicted Label: 1
# Word: histoire, True Label: 8, Predicted Label: 1
# Word: ., True Label: 1, Predicted Label: 1
# Word: La, True Label: 1, Predicted Label: 1
# Word: présence, True Label: 7, Predicted Label: 1
# Word: d', True Label: 1, Predicted Label: 1
# Word: une, True Label: 1, Predicted Label: 1
# Word: abondante, True Label: 1, Predicted Label: 1
# Word: forêt, True Label: 10, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: fournissant, True Label: 1, Predicted Label: 1
# Word: l', True Label: 1, Predicted Label: 1
# Word: indispensable, True Label: 1, Predicted Label: 1
# Word: combustible, True Label: 11, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: liée, True Label: 1, Predicted Label: 1
# Word: à, True Label: 1, Predicted Label: 1
# Word: l', True Label: 1, Predicted Label: 1
# Word: existence, True Label: 7, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: le, True Label: 1, Predicted Label: 1
# Word: minerai, True Label: 1, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: fer, True Label: 1, Predicted Label: 1
# Word: exploitable, True Label: 1, Predicted Label: 1
# Word: à, True Label: 1, Predicted Label: 1
# Word: ciel, True Label: 1, Predicted Label: 1
# Word: ouvert, True Label: 1, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: a, True Label: 1, Predicted Label: 1
# Word: incité, True Label: 1, Predicted Label: 1
# Word: les, True Label: 1, Predicted Label: 1
# Word: hommes, True Label: 0, Predicted Label: 1
# Word: à, True Label: 1, Predicted Label: 1
# Word: créer, True Label: 1, Predicted Label: 1
# Word: ", True Label: 1, Predicted Label: 1
# Word: ., True Label: 1, Predicted Label: 1
# Word: Un, True Label: 1, Predicted Label: 1
# Word: voyage, True Label: 2, Predicted Label: 1
# Word: étonnant, True Label: 1, Predicted Label: 1
# Word: où, True Label: 1, Predicted Label: 1
# Word: photos, True Label: 5, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: réalisations, True Label: 5, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: vieux, True Label: 1, Predicted Label: 1
# Word: outils, True Label: 5, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: documents, True Label: 8, Predicted Label: 1
# Word: anciens, True Label: 1, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: permettront, True Label: 1, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: mesurer, True Label: 1, Predicted Label: 1
# Word: combien, True Label: 1, Predicted Label: 1
# Word: ce, True Label: 1, Predicted Label: 1
# Word: petit, True Label: 1, Predicted Label: 1
# Word: bout, True Label: 12, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: terre, True Label: 6, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: France, True Label: 4, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: situé, True Label: 1, Predicted Label: 1
# Word: à, True Label: 1, Predicted Label: 1
# Word: les, True Label: 1, Predicted Label: 1
# Word: Marches, True Label: 1, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: l', True Label: 1, Predicted Label: 1
# Word: Est, True Label: 6, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: lieu, True Label: 6, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: passage, True Label: 2, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: prédilection, True Label: 9, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: les, True Label: 1, Predicted Label: 1
# Word: invasions, True Label: 2, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: fut, True Label: 1, Predicted Label: 1
# Word: une, True Label: 1, Predicted Label: 1
# Word: terre, True Label: 6, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: labeur, True Label: 2, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: et, True Label: 1, Predicted Label: 1
# Word: combien, True Label: 1, Predicted Label: 1
# Word: le, True Label: 1, Predicted Label: 1
# Word: travail, True Label: 2, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: ses, True Label: 1, Predicted Label: 1
# Word: habitants, True Label: 0, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: durs, True Label: 1, Predicted Label: 1
# Word: à, True Label: 1, Predicted Label: 1
# Word: la, True Label: 1, Predicted Label: 1
# Word: tâche, True Label: 1, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: doit, True Label: 1, Predicted Label: 1
# Word: être, True Label: 1, Predicted Label: 1
# Word: reconnu, True Label: 1, Predicted Label: 1
# Word: et, True Label: 1, Predicted Label: 1
# Word: mis, True Label: 1, Predicted Label: 1
# Word: en, True Label: 1, Predicted Label: 1
# Word: valeur, True Label: 1, Predicted Label: 1
# Word: ., True Label: 1, Predicted Label: 1
# Word: Cette, True Label: 1, Predicted Label: 1
# Word: exposition, True Label: 2, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: comme, True Label: 1, Predicted Label: 1
# Word: devait, True Label: 1, Predicted Label: 1
# Word: conclure, True Label: 1, Predicted Label: 1
# Word: Roger, True Label: 1, Predicted Label: 1
# Word: Thiriot, True Label: 1, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: ", True Label: 1, Predicted Label: 1
# Word: n', True Label: 1, Predicted Label: 1
# Word: a, True Label: 1, Predicted Label: 1
# Word: d', True Label: 1, Predicted Label: 1
# Word: autre, True Label: 1, Predicted Label: 1
# Word: ambition, True Label: 13, Predicted Label: 1
# Word: que, True Label: 1, Predicted Label: 1
# Word: d', True Label: 1, Predicted Label: 1
# Word: apporter, True Label: 1, Predicted Label: 1
# Word: un, True Label: 1, Predicted Label: 1
# Word: modeste, True Label: 1, Predicted Label: 1
# Word: témoignage, True Label: 8, Predicted Label: 1
# Word: sur, True Label: 1, Predicted Label: 1
# Word: le, True Label: 1, Predicted Label: 1
# Word: passé, True Label: 3, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: le, True Label: 1, Predicted Label: 1
# Word: tissu, True Label: 1, Predicted Label: 1
# Word: économique, True Label: 1, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: la, True Label: 1, Predicted Label: 1
# Word: région, True Label: 6, Predicted Label: 1
# Word: ., True Label: 1, Predicted Label: 1
# Word: Elle, True Label: 1, Predicted Label: 1
# Word: se, True Label: 1, Predicted Label: 1
# Word: veut, True Label: 1, Predicted Label: 1
# Word: aussi, True Label: 1, Predicted Label: 1
# Word: message, True Label: 8, Predicted Label: 1
# Word: d', True Label: 1, Predicted Label: 1
# Word: espoir, True Label: 9, Predicted Label: 1
# Word: en, True Label: 1, Predicted Label: 1
# Word: l', True Label: 1, Predicted Label: 1
# Word: avenir, True Label: 3, Predicted Label: 1
# Word: ", True Label: 1, Predicted Label: 1
# Word: ., True Label: 1, Predicted Label: 1
# Word: Une, True Label: 1, Predicted Label: 1
# Word: nouvelle, True Label: 1, Predicted Label: 1
# Word: école, True Label: 4, Predicted Label: 1
# Word: pour, True Label: 1, Predicted Label: 1
# Word: la, True Label: 1, Predicted Label: 1
# Word: commune, True Label: 4, Predicted Label: 1
# Word: À, True Label: 1, Predicted Label: 1
# Word: le, True Label: 1, Predicted Label: 1
# Word: cours, True Label: 1, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: la, True Label: 1, Predicted Label: 1
# Word: cérémonie, True Label: 2, Predicted Label: 1
# Word: d', True Label: 1, Predicted Label: 1
# Word: inauguration, True Label: 2, Predicted Label: 1
# Word: ., True Label: 1, Predicted Label: 1
# Word: La, True Label: 1, Predicted Label: 1
# Word: nouvelle, True Label: 1, Predicted Label: 1
# Word: école, True Label: 1, Predicted Label: 1
# Word: maternelle, True Label: 1, Predicted Label: 1
# Word: a, True Label: 1, Predicted Label: 1
# Word: été, True Label: 1, Predicted Label: 1
# Word: inaugurée, True Label: 1, Predicted Label: 1
# Word: en, True Label: 1, Predicted Label: 1
# Word: présence, True Label: 7, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: le, True Label: 1, Predicted Label: 1
# Word: sous-préfet, True Label: 0, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: le, True Label: 1, Predicted Label: 1
# Word: président, True Label: 1, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: le, True Label: 1, Predicted Label: 1
# Word: conseil, True Label: 1, Predicted Label: 1
# Word: général, True Label: 1, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: accompagné, True Label: 1, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: MM., True Label: 0, Predicted Label: 1
# Word: Farinet, True Label: 0, Predicted Label: 1
# Word: et, True Label: 1, Predicted Label: 1
# Word: Verneau, True Label: 0, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: les, True Label: 1, Predicted Label: 1
# Word: maires, True Label: 0, Predicted Label: 1
# Word: et, True Label: 1, Predicted Label: 1
# Word: représentants, True Label: 0, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: la, True Label: 1, Predicted Label: 1
# Word: communauté, True Label: 1, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: communes, True Label: 1, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: l', True Label: 1, Predicted Label: 1
# Word: inspecteur, True Label: 1, Predicted Label: 1
# Word: d', True Label: 1, Predicted Label: 1
# Word: académie, True Label: 1, Predicted Label: 1
# Word: et, True Label: 1, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: l', True Label: 1, Predicted Label: 1
# Word: inspectrice, True Label: 1, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: l', True Label: 1, Predicted Label: 1
# Word: Education, True Label: 1, Predicted Label: 1
# Word: nationale, True Label: 1, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: la, True Label: 1, Predicted Label: 1
# Word: circonscription, True Label: 4, Predicted Label: 1
# Word: ., True Label: 1, Predicted Label: 1
# Word: Dans, True Label: 1, Predicted Label: 1
# Word: son, True Label: 1, Predicted Label: 1
# Word: intervention, True Label: 8, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: M., True Label: 0, Predicted Label: 1
# Word: Soyer, True Label: 0, Predicted Label: 1
# Word: a, True Label: 1, Predicted Label: 1
# Word: fait, True Label: 1, Predicted Label: 1
# Word: l', True Label: 1, Predicted Label: 1
# Word: historique, True Label: 8, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: l', True Label: 1, Predicted Label: 1
# Word: école, True Label: 1, Predicted Label: 1
# Word: maternelle, True Label: 1, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: qui, True Label: 1, Predicted Label: 1
# Word: existe, True Label: 1, Predicted Label: 1
# Word: à, True Label: 1, Predicted Label: 1
# Word: Vignot, True Label: 4, Predicted Label: 1
# Word: depuis, True Label: 1, Predicted Label: 1
# Word: 1972, True Label: 3, Predicted Label: 1
# Word: ., True Label: 1, Predicted Label: 1
# Word: Elle, True Label: 1, Predicted Label: 1
# Word: occupait, True Label: 1, Predicted Label: 1
# Word: depuis, True Label: 1, Predicted Label: 1
# Word: cette, True Label: 1, Predicted Label: 1
# Word: date, True Label: 3, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: un, True Label: 1, Predicted Label: 1
# Word: bâtiment, True Label: 5, Predicted Label: 1
# Word: préfabriqué, True Label: 1, Predicted Label: 1
# Word: dans, True Label: 1, Predicted Label: 1
# Word: le, True Label: 1, Predicted Label: 1
# Word: parc, True Label: 1, Predicted Label: 1
# Word: Verneau, True Label: 0, Predicted Label: 1
# Word: ., True Label: 1, Predicted Label: 1
# Word: En, True Label: 1, Predicted Label: 1
# Word: 1996, True Label: 3, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: la, True Label: 1, Predicted Label: 1
# Word: municipalité, True Label: 4, Predicted Label: 1
# Word: étudie, True Label: 1, Predicted Label: 1
# Word: la, True Label: 1, Predicted Label: 1
# Word: possibilité, True Label: 7, Predicted Label: 1
# Word: d', True Label: 1, Predicted Label: 1
# Word: une, True Label: 1, Predicted Label: 1
# Word: construction, True Label: 5, Predicted Label: 1
# Word: neuve, True Label: 1, Predicted Label: 1
# Word: ., True Label: 1, Predicted Label: 1
# Word: Le, True Label: 1, Predicted Label: 1
# Word: coût, True Label: 14, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: les, True Label: 1, Predicted Label: 1
# Word: bâtiments, True Label: 5, Predicted Label: 1
# Word: s', True Label: 1, Predicted Label: 1
# Word: élève, True Label: 1, Predicted Label: 1
# Word: à, True Label: 1, Predicted Label: 1
# Word: 2.700.000, True Label: 1, Predicted Label: 1
# Word: F, True Label: 14, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: dont, True Label: 1, Predicted Label: 1
# Word: 40, True Label: 1, Predicted Label: 1
# Word: %, True Label: 15, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: subvention, True Label: 2, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: l', True Label: 1, Predicted Label: 1
# Word: Etat, True Label: 4, Predicted Label: 1
# Word: ;, True Label: 1, Predicted Label: 1
# Word: 20, True Label: 1, Predicted Label: 1
# Word: %, True Label: 15, Predicted Label: 1
# Word: d', True Label: 1, Predicted Label: 1
# Word: auto-financement, True Label: 14, Predicted Label: 1
# Word: et, True Label: 1, Predicted Label: 1
# Word: 40, True Label: 1, Predicted Label: 1
# Word: %, True Label: 15, Predicted Label: 1
# Word: d', True Label: 1, Predicted Label: 1
# Word: emprunt, True Label: 14, Predicted Label: 1
# Word: ., True Label: 1, Predicted Label: 1
# Word: Le, True Label: 1, Predicted Label: 1
# Word: mobilier, True Label: 5, Predicted Label: 1
# Word: est, True Label: 1, Predicted Label: 1
# Word: subventionné, True Label: 1, Predicted Label: 1
# Word: à, True Label: 1, Predicted Label: 1
# Word: 50, True Label: 1, Predicted Label: 1
# Word: %, True Label: 15, Predicted Label: 1
# Word: par, True Label: 1, Predicted Label: 1
# Word: le, True Label: 1, Predicted Label: 1
# Word: conseil, True Label: 1, Predicted Label: 1
# Word: général, True Label: 1, Predicted Label: 1
# Word: ., True Label: 1, Predicted Label: 1
# Word: M., True Label: 0, Predicted Label: 1
# Word: Soyer, True Label: 0, Predicted Label: 1
# Word: a, True Label: 1, Predicted Label: 1
# Word: adressé, True Label: 1, Predicted Label: 1
# Word: ses, True Label: 1, Predicted Label: 1
# Word: remerciements, True Label: 8, Predicted Label: 1
# Word: à, True Label: 1, Predicted Label: 1
# Word: les, True Label: 1, Predicted Label: 1
# Word: collectivités, True Label: 4, Predicted Label: 1
# Word: participantes, True Label: 1, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: et, True Label: 1, Predicted Label: 1
# Word: en, True Label: 1, Predicted Label: 1
# Word: particulier, True Label: 1, Predicted Label: 1
# Word: à, True Label: 1, Predicted Label: 1
# Word: l', True Label: 1, Predicted Label: 1
# Word: inspecteur, True Label: 1, Predicted Label: 1
# Word: d', True Label: 1, Predicted Label: 1
# Word: académie, True Label: 1, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: pour, True Label: 1, Predicted Label: 1
# Word: la, True Label: 1, Predicted Label: 1
# Word: création, True Label: 2, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: en, True Label: 1, Predicted Label: 1
# Word: 1998, True Label: 3, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: d', True Label: 1, Predicted Label: 1
# Word: une, True Label: 1, Predicted Label: 1
# Word: cinquième, True Label: 1, Predicted Label: 1
# Word: classe, True Label: 0, Predicted Label: 1
# Word: et, True Label: 1, Predicted Label: 1
# Word: la, True Label: 1, Predicted Label: 1
# Word: nomination, True Label: 2, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: deux, True Label: 1, Predicted Label: 1
# Word: aides-éducateurs, True Label: 0, Predicted Label: 1
# Word: et, True Label: 1, Predicted Label: 1
# Word: la, True Label: 1, Predicted Label: 1
# Word: mise, True Label: 1, Predicted Label: 1
# Word: à, True Label: 1, Predicted Label: 1
# Word: disposition, True Label: 1, Predicted Label: 1
# Word: à, True Label: 1, Predicted Label: 1
# Word: la, True Label: 1, Predicted Label: 1
# Word: rentrée, True Label: 2, Predicted Label: 1
# Word: 1999, True Label: 3, Predicted Label: 1
# Word: d', True Label: 1, Predicted Label: 1
# Word: un, True Label: 1, Predicted Label: 1
# Word: titulaire, True Label: 1, Predicted Label: 1
# Word: mobile, True Label: 1, Predicted Label: 1
# Word: ., True Label: 1, Predicted Label: 1
# Word: M., True Label: 0, Predicted Label: 1
# Word: Dumez, True Label: 0, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: président, True Label: 0, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: le, True Label: 1, Predicted Label: 1
# Word: conseil, True Label: 1, Predicted Label: 1
# Word: général, True Label: 1, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: a, True Label: 1, Predicted Label: 1
# Word: parlé, True Label: 1, Predicted Label: 1
# Word: d', True Label: 1, Predicted Label: 1
# Word: une, True Label: 1, Predicted Label: 1
# Word: ", True Label: 1, Predicted Label: 1
# Word: réalisation, True Label: 2, Predicted Label: 1
# Word: apte, True Label: 1, Predicted Label: 1
# Word: à, True Label: 1, Predicted Label: 1
# Word: l', True Label: 1, Predicted Label: 1
# Word: épanouissement, True Label: 16, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: les, True Label: 1, Predicted Label: 1
# Word: petits, True Label: 0, Predicted Label: 1
# Word: ", True Label: 1, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: non, True Label: 1, Predicted Label: 1
# Word: sans, True Label: 1, Predicted Label: 1
# Word: rappeler, True Label: 1, Predicted Label: 1
# Word: le, True Label: 1, Predicted Label: 1
# Word: rôle, True Label: 7, Predicted Label: 1
# Word: primordial, True Label: 1, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: l', True Label: 1, Predicted Label: 1
# Word: éducation, True Label: 2, Predicted Label: 1
# Word: familiale, True Label: 1, Predicted Label: 1
# Word: ., True Label: 1, Predicted Label: 1
# Word: L', True Label: 1, Predicted Label: 1
# Word: inspecteur, True Label: 1, Predicted Label: 1
# Word: d', True Label: 1, Predicted Label: 1
# Word: académie, True Label: 1, Predicted Label: 1
# Word: a, True Label: 1, Predicted Label: 1
# Word: remercié, True Label: 1, Predicted Label: 1
# Word: la, True Label: 1, Predicted Label: 1
# Word: municipalité, True Label: 4, Predicted Label: 1
# Word: d', True Label: 1, Predicted Label: 1
# Word: avoir, True Label: 1, Predicted Label: 1
# Word: mené, True Label: 1, Predicted Label: 1
# Word: à, True Label: 1, Predicted Label: 1
# Word: bien, True Label: 1, Predicted Label: 1
# Word: son, True Label: 1, Predicted Label: 1
# Word: projet, True Label: 8, Predicted Label: 1
# Word: en, True Label: 1, Predicted Label: 1
# Word: ayant, True Label: 1, Predicted Label: 1
# Word: associé, True Label: 1, Predicted Label: 1
# Word: les, True Label: 1, Predicted Label: 1
# Word: différentes, True Label: 1, Predicted Label: 1
# Word: parties, True Label: 0, Predicted Label: 1
# Word: intéressées, True Label: 1, Predicted Label: 1
# Word: :, True Label: 1, Predicted Label: 1
# Word: enseignants, True Label: 0, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: parents, True Label: 0, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: pour, True Label: 1, Predicted Label: 1
# Word: la, True Label: 1, Predicted Label: 1
# Word: conception, True Label: 2, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: les, True Label: 1, Predicted Label: 1
# Word: locaux, True Label: 5, Predicted Label: 1
# Word: et, True Label: 1, Predicted Label: 1
# Word: la, True Label: 1, Predicted Label: 1
# Word: qualité, True Label: 13, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: les, True Label: 1, Predicted Label: 1
# Word: matériaux, True Label: 5, Predicted Label: 1
# Word: utilisés, True Label: 1, Predicted Label: 1
# Word: ., True Label: 1, Predicted Label: 1
# Word: Les, True Label: 1, Predicted Label: 1
# Word: enfants, True Label: 0, Predicted Label: 1
# Word: et, True Label: 1, Predicted Label: 1
# Word: les, True Label: 1, Predicted Label: 1
# Word: pêcheurs, True Label: 0, Predicted Label: 1
# Word: Ce, True Label: 1, Predicted Label: 1
# Word: sont, True Label: 1, Predicted Label: 1
# Word: finalement, True Label: 1, Predicted Label: 1
# Word: les, True Label: 1, Predicted Label: 1
# Word: élèves, True Label: 0, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: la, True Label: 1, Predicted Label: 1
# Word: classe, True Label: 0, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: CM2, True Label: 4, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: Jacky, True Label: 1, Predicted Label: 1
# Word: Hedin, True Label: 1, Predicted Label: 1
# Word: qui, True Label: 1, Predicted Label: 1
# Word: sont, True Label: 1, Predicted Label: 1
# Word: venus, True Label: 1, Predicted Label: 1
# Word: mettre, True Label: 1, Predicted Label: 1
# Word: la, True Label: 1, Predicted Label: 1
# Word: main, True Label: 1, Predicted Label: 1
# Word: à, True Label: 1, Predicted Label: 1
# Word: le, True Label: 1, Predicted Label: 1
# Word: sac, True Label: 1, Predicted Label: 1
# Word: poubelle, True Label: 1, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: dans, True Label: 1, Predicted Label: 1
# Word: la, True Label: 1, Predicted Label: 1
# Word: bonne, True Label: 1, Predicted Label: 1
# Word: humeur, True Label: 9, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: comme, True Label: 1, Predicted Label: 1
# Word: s', True Label: 1, Predicted Label: 1
# Word: ils, True Label: 1, Predicted Label: 1
# Word: étaient, True Label: 1, Predicted Label: 1
# Word: là, True Label: 1, Predicted Label: 1
# Word: pour, True Label: 1, Predicted Label: 1
# Word: participer, True Label: 1, Predicted Label: 1
# Word: à, True Label: 1, Predicted Label: 1
# Word: un, True Label: 1, Predicted Label: 1
# Word: jeu, True Label: 2, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: plein-air, True Label: 1, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: laissant, True Label: 1, Predicted Label: 1
# Word: à, True Label: 1, Predicted Label: 1
# Word: le, True Label: 1, Predicted Label: 1
# Word: passage, True Label: 1, Predicted Label: 1
# Word: le, True Label: 1, Predicted Label: 1
# Word: soin, True Label: 1, Predicted Label: 1
# Word: à, True Label: 1, Predicted Label: 1
# Word: leurs, True Label: 1, Predicted Label: 1
# Word: aînés, True Label: 0, Predicted Label: 1
# Word: d', True Label: 1, Predicted Label: 1
# Word: en, True Label: 1, Predicted Label: 1
# Word: tirer, True Label: 1, Predicted Label: 1
# Word: une, True Label: 1, Predicted Label: 1
# Word: morale, True Label: 8, Predicted Label: 1
# Word: ., True Label: 1, Predicted Label: 1
# Word: Une, True Label: 1, Predicted Label: 1
# Word: seconde, True Label: 1, Predicted Label: 1
# Word: opération, True Label: 2, Predicted Label: 1
# Word: se, True Label: 1, Predicted Label: 1
# Word: déroulait, True Label: 1, Predicted Label: 1
# Word: en, True Label: 1, Predicted Label: 1
# Word: parallèle, True Label: 1, Predicted Label: 1
# Word: sur, True Label: 1, Predicted Label: 1
# Word: le, True Label: 1, Predicted Label: 1
# Word: territoire, True Label: 5, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: la, True Label: 1, Predicted Label: 1
# Word: commune, True Label: 4, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: avec, True Label: 1, Predicted Label: 1
# Word: un, True Label: 1, Predicted Label: 1
# Word: groupe, True Label: 17, Predicted Label: 1
# Word: d', True Label: 1, Predicted Label: 1
# Word: une, True Label: 1, Predicted Label: 1
# Word: dizaine, True Label: 15, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: chevaliers, True Label: 1, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: la, True Label: 1, Predicted Label: 1
# Word: gaule, True Label: 1, Predicted Label: 1
# Word: ", True Label: 1, Predicted Label: 1
# Word: La, True Label: 1, Predicted Label: 1
# Word: Barisienne, True Label: 1, Predicted Label: 1
# Word: ", True Label: 1, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: des, True Label: 1, Predicted Label: 1
# Word: pêcheurs, True Label: 0, Predicted Label: 1
# Word: à, True Label: 1, Predicted Label: 1
# Word: la, True Label: 1, Predicted Label: 1
# Word: ligne, True Label: 1, Predicted Label: 1
# Word: venus, True Label: 1, Predicted Label: 1
# Word: nettoyer, True Label: 1, Predicted Label: 1
# Word: les, True Label: 1, Predicted Label: 1
# Word: rives, True Label: 6, Predicted Label: 1
# Word: et, True Label: 1, Predicted Label: 1
# Word: curer, True Label: 1, Predicted Label: 1
# Word: le, True Label: 1, Predicted Label: 1
# Word: petit, True Label: 1, Predicted Label: 1
# Word: ruisseau, True Label: 6, Predicted Label: 1
# Word: qui, True Label: 1, Predicted Label: 1
# Word: serpente, True Label: 1, Predicted Label: 1
# Word: sous, True Label: 1, Predicted Label: 1
# Word: les, True Label: 1, Predicted Label: 1
# Word: ", True Label: 1, Predicted Label: 1
# Word: Sources, True Label: 4, Predicted Label: 1
# Word: ", True Label: 1, Predicted Label: 1
# Word: avant, True Label: 1, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: se, True Label: 1, Predicted Label: 1
# Word: jeter, True Label: 1, Predicted Label: 1
# Word: dans, True Label: 1, Predicted Label: 1
# Word: l', True Label: 1, Predicted Label: 1
# Word: Ornain, True Label: 4, Predicted Label: 1
# Word: ., True Label: 1, Predicted Label: 1
# Word: Une, True Label: 1, Predicted Label: 1
# Word: opération, True Label: 2, Predicted Label: 1
# Word: destinée, True Label: 1, Predicted Label: 1
# Word: aussi, True Label: 1, Predicted Label: 1
# Word: à, True Label: 1, Predicted Label: 1
# Word: faciliter, True Label: 1, Predicted Label: 1
# Word: la, True Label: 1, Predicted Label: 1
# Word: remontée, True Label: 2, Predicted Label: 1
# Word: et, True Label: 1, Predicted Label: 1
# Word: la, True Label: 1, Predicted Label: 1
# Word: fraye, True Label: 2, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: les, True Label: 1, Predicted Label: 1
# Word: truites, True Label: 18, Predicted Label: 1
# Word: vers, True Label: 1, Predicted Label: 1
# Word: la, True Label: 1, Predicted Label: 1
# Word: rivière, True Label: 6, Predicted Label: 1
# Word: ., True Label: 1, Predicted Label: 1
# Word: Les, True Label: 1, Predicted Label: 1
# Word: petits, True Label: 1, Predicted Label: 1
# Word: mitrons, True Label: 0, Predicted Label: 1
# Word: séduits, True Label: 1, Predicted Label: 1
# Word: par, True Label: 1, Predicted Label: 1
# Word: la, True Label: 1, Predicted Label: 1
# Word: bonne, True Label: 1, Predicted Label: 1
# Word: odeur, True Label: 13, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: le, True Label: 1, Predicted Label: 1
# Word: pain, True Label: 19, Predicted Label: 1
# Word: ., True Label: 1, Predicted Label: 1
# Word: Depuis, True Label: 1, Predicted Label: 1
# Word: quatre, True Label: 1, Predicted Label: 1
# Word: ans, True Label: 3, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: les, True Label: 1, Predicted Label: 1
# Word: boulangers, True Label: 0, Predicted Label: 1
# Word: français, True Label: 1, Predicted Label: 1
# Word: fêtent, True Label: 1, Predicted Label: 1
# Word: avec, True Label: 1, Predicted Label: 1
# Word: leurs, True Label: 1, Predicted Label: 1
# Word: clients, True Label: 0, Predicted Label: 1
# Word: la, True Label: 1, Predicted Label: 1
# Word: Saint-Honoré, True Label: 2, Predicted Label: 1
# Word: ., True Label: 1, Predicted Label: 1
# Word: Ceux, True Label: 1, Predicted Label: 1
# Word: d', True Label: 1, Predicted Label: 1
# Word: Ancerville, True Label: 4, Predicted Label: 1
# Word: ont, True Label: 1, Predicted Label: 1
# Word: participé, True Label: 1, Predicted Label: 1
# Word: à, True Label: 1, Predicted Label: 1
# Word: l', True Label: 1, Predicted Label: 1
# Word: événement, True Label: 2, Predicted Label: 1
# Word: en, True Label: 1, Predicted Label: 1
# Word: faisant, True Label: 1, Predicted Label: 1
# Word: découvrir, True Label: 1, Predicted Label: 1
# Word: leur, True Label: 1, Predicted Label: 1
# Word: savoir-faire, True Label: 8, Predicted Label: 1
# Word: et, True Label: 1, Predicted Label: 1
# Word: leurs, True Label: 1, Predicted Label: 1
# Word: recettes, True Label: 8, Predicted Label: 1
# Word: ., True Label: 1, Predicted Label: 1
# Word: Les, True Label: 1, Predicted Label: 1
# Word: élèves, True Label: 0, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: la, True Label: 1, Predicted Label: 1
# Word: classe, True Label: 0, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: CE1, True Label: 4, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: l', True Label: 1, Predicted Label: 1
# Word: école, True Label: 1, Predicted Label: 1
# Word: Notre-Dame, True Label: 0, Predicted Label: 1
# Word: ont, True Label: 1, Predicted Label: 1
# Word: pris, True Label: 1, Predicted Label: 1
# Word: part, True Label: 1, Predicted Label: 1
# Word: à, True Label: 1, Predicted Label: 1
# Word: les, True Label: 1, Predicted Label: 1
# Word: festivités, True Label: 2, Predicted Label: 1
# Word: ., True Label: 1, Predicted Label: 1
# Word: Ils, True Label: 1, Predicted Label: 1
# Word: ont, True Label: 1, Predicted Label: 1
# Word: été, True Label: 1, Predicted Label: 1
# Word: reçus, True Label: 1, Predicted Label: 1
# Word: à, True Label: 1, Predicted Label: 1
# Word: la, True Label: 1, Predicted Label: 1
# Word: boulangerie, True Label: 1, Predicted Label: 1
# Word: Leroy, True Label: 0, Predicted Label: 1
# Word: pour, True Label: 1, Predicted Label: 1
# Word: visiter, True Label: 1, Predicted Label: 1
# Word: le, True Label: 1, Predicted Label: 1
# Word: fournil, True Label: 5, Predicted Label: 1
# Word: et, True Label: 1, Predicted Label: 1
# Word: surtout, True Label: 1, Predicted Label: 1
# Word: pétrir, True Label: 1, Predicted Label: 1
# Word: la, True Label: 1, Predicted Label: 1
# Word: pâte, True Label: 19, Predicted Label: 1
# Word: afin, True Label: 1, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: confectionner, True Label: 1, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: délicieux, True Label: 1, Predicted Label: 1
# Word: pains, True Label: 1, Predicted Label: 1
# Word: à, True Label: 1, Predicted Label: 1
# Word: le, True Label: 1, Predicted Label: 1
# Word: chocolat, True Label: 1, Predicted Label: 1
# Word: qu', True Label: 1, Predicted Label: 1
# Word: ils, True Label: 1, Predicted Label: 1
# Word: ont, True Label: 1, Predicted Label: 1
# Word: dégustés, True Label: 1, Predicted Label: 1
# Word: à, True Label: 1, Predicted Label: 1
# Word: l', True Label: 1, Predicted Label: 1
# Word: heure, True Label: 3, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: le, True Label: 1, Predicted Label: 1
# Word: goûter, True Label: 2, Predicted Label: 1
# Word: avec, True Label: 1, Predicted Label: 1
# Word: un, True Label: 1, Predicted Label: 1
# Word: verre, True Label: 15, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: jus, True Label: 19, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: fruit, True Label: 19, Predicted Label: 1
# Word: ., True Label: 1, Predicted Label: 1
# Word: Quel, True Label: 1, Predicted Label: 1
# Word: bonheur, True Label: 9, Predicted Label: 1
# Word: d', True Label: 1, Predicted Label: 1
# Word: entendre, True Label: 1, Predicted Label: 1
# Word: la, True Label: 1, Predicted Label: 1
# Word: boulangère, True Label: 0, Predicted Label: 1
# Word: conter, True Label: 1, Predicted Label: 1
# Word: l', True Label: 1, Predicted Label: 1
# Word: histoire, True Label: 8, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: saint, True Label: 0, Predicted Label: 1
# Word: Honoré, True Label: 0, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: ce, True Label: 1, Predicted Label: 1
# Word: jeune, True Label: 1, Predicted Label: 1
# Word: homme, True Label: 1, Predicted Label: 1
# Word: dissipé, True Label: 1, Predicted Label: 1
# Word: annonçant, True Label: 1, Predicted Label: 1
# Word: à, True Label: 1, Predicted Label: 1
# Word: sa, True Label: 1, Predicted Label: 1
# Word: vieille, True Label: 1, Predicted Label: 1
# Word: nourrice, True Label: 0, Predicted Label: 1
# Word: qu', True Label: 1, Predicted Label: 1
# Word: il, True Label: 1, Predicted Label: 1
# Word: voulait, True Label: 1, Predicted Label: 1
# Word: se, True Label: 1, Predicted Label: 1
# Word: faire, True Label: 1, Predicted Label: 1
# Word: prêtre, True Label: 0, Predicted Label: 1
# Word: !, True Label: 1, Predicted Label: 1
# Word: Bref, True Label: 1, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: en, True Label: 1, Predicted Label: 1
# Word: quittant, True Label: 1, Predicted Label: 1
# Word: le, True Label: 1, Predicted Label: 1
# Word: fournil, True Label: 5, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: chacun, True Label: 1, Predicted Label: 1
# Word: ne, True Label: 1, Predicted Label: 1
# Word: rêvait, True Label: 1, Predicted Label: 1
# Word: que, True Label: 1, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: remettre, True Label: 1, Predicted Label: 1
# Word: la, True Label: 1, Predicted Label: 1
# Word: main, True Label: 1, Predicted Label: 1
# Word: à, True Label: 1, Predicted Label: 1
# Word: la, True Label: 1, Predicted Label: 1
# Word: pâte, True Label: 1, Predicted Label: 1
# Word: avec, True Label: 1, Predicted Label: 1
# Word: Sylvie, True Label: 0, Predicted Label: 1
# Word: et, True Label: 1, Predicted Label: 1
# Word: Daniel, True Label: 0, Predicted Label: 1
# Word: ., True Label: 1, Predicted Label: 1
# Word: L', True Label: 1, Predicted Label: 1
# Word: agenda, True Label: 8, Predicted Label: 1
# Word: sportif, True Label: 1, Predicted Label: 1
# Word: Football, True Label: 2, Predicted Label: 1
# Word: Une, True Label: 1, Predicted Label: 1
# Word: seule, True Label: 1, Predicted Label: 1
# Word: rencontre, True Label: 2, Predicted Label: 1
# Word: est, True Label: 1, Predicted Label: 1
# Word: à, True Label: 1, Predicted Label: 1
# Word: le, True Label: 1, Predicted Label: 1
# Word: programme, True Label: 1, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: les, True Label: 1, Predicted Label: 1
# Word: licenciés, True Label: 0, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: le, True Label: 1, Predicted Label: 1
# Word: FC, True Label: 4, Predicted Label: 1
# Word: aujourd'hui, True Label: 1, Predicted Label: 1
# Word: ., True Label: 1, Predicted Label: 1
# Word: L', True Label: 1, Predicted Label: 1
# Word: équipe, True Label: 0, Predicted Label: 1
# Word: B, True Label: 13, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: chez, True Label: 1, Predicted Label: 1
# Word: les, True Label: 1, Predicted Label: 1
# Word: seniors, True Label: 0, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: évoluera, True Label: 1, Predicted Label: 1
# Word: à, True Label: 1, Predicted Label: 1
# Word: partir, True Label: 1, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: 15, True Label: 1, Predicted Label: 1
# Word: h, True Label: 3, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: sur, True Label: 1, Predicted Label: 1
# Word: la, True Label: 1, Predicted Label: 1
# Word: pelouse, True Label: 5, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: le, True Label: 1, Predicted Label: 1
# Word: terrain, True Label: 1, Predicted Label: 1
# Word: d', True Label: 1, Predicted Label: 1
# Word: honneur, True Label: 1, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: face, True Label: 1, Predicted Label: 1
# Word: à, True Label: 1, Predicted Label: 1
# Word: la, True Label: 1, Predicted Label: 1
# Word: formation, True Label: 0, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: Laneuville, True Label: 4, Predicted Label: 1
# Word: ., True Label: 1, Predicted Label: 1
# Word: Une, True Label: 1, Predicted Label: 1
# Word: journée, True Label: 3, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: le, True Label: 1, Predicted Label: 1
# Word: championnat, True Label: 2, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: promotion, True Label: 2, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: première, True Label: 1, Predicted Label: 1
# Word: division, True Label: 0, Predicted Label: 1
# Word: départementale, True Label: 1, Predicted Label: 1
# Word: ., True Label: 1, Predicted Label: 1
# Word: Cet, True Label: 1, Predicted Label: 1
# Word: entraînement, True Label: 2, Predicted Label: 1
# Word: sera, True Label: 1, Predicted Label: 1
# Word: renouvelé, True Label: 1, Predicted Label: 1
# Word: demain, True Label: 1, Predicted Label: 1
# ...
# Word: ,, True Label: 1, Predicted Label: 1
# Word: il, True Label: 1, Predicted Label: 1
# Word: semble, True Label: 1, Predicted Label: 1
# Word: que, True Label: 1, Predicted Label: 1
# Word: la, True Label: 1, Predicted Label: 1
# Word: France, True Label: 4, Predicted Label: 1
# Word: ait, True Label: 1, Predicted Label: 1
# Word: cherché, True Label: 1, Predicted Label: 1
# Word: à, True Label: 1, Predicted Label: 1
# Word: sauver, True Label: 1, Predicted Label: 1
# Word: à, True Label: 1, Predicted Label: 1
# Word: le, True Label: 1, Predicted Label: 1
# Word: moins, True Label: 1, Predicted Label: 1
# Word: l', True Label: 1, Predicted Label: 1
# Word: Institut, True Label: 4, Predicted Label: 1
# Word: d', True Label: 1, Predicted Label: 1
# Word: émission, True Label: 2, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: pièce, True Label: 1, Predicted Label: 1
# Word: maîtresse, True Label: 1, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: sa, True Label: 1, Predicted Label: 1
# Word: diplomatie, True Label: 2, Predicted Label: 1
# Word: financière, True Label: 1, Predicted Label: 1
# Word: en, True Label: 1, Predicted Label: 1
# Word: Indochine, True Label: 4, Predicted Label: 1
# Word: ., True Label: 1, Predicted Label: 1
# Word: le, True Label: 1, Predicted Label: 1
# Word: 12, True Label: 3, Predicted Label: 1
# Word: décembre, True Label: 1, Predicted Label: 1
# Word: suivant, True Label: 1, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: L', True Label: 1, Predicted Label: 1
# Word: Assemblée, True Label: 1, Predicted Label: 1
# Word: nationale, True Label: 1, Predicted Label: 1
# Word: décida, True Label: 1, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: tenir, True Label: 1, Predicted Label: 1
# Word: secrets, True Label: 1, Predicted Label: 1
# Word: les, True Label: 1, Predicted Label: 1
# Word: travaux, True Label: 5, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: cette, True Label: 1, Predicted Label: 1
# Word: commission, True Label: 4, Predicted Label: 1
# Word: ., True Label: 1, Predicted Label: 1
# Word: En, True Label: 1, Predicted Label: 1
# Word: juillet, True Label: 3, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: l', True Label: 1, Predicted Label: 1
# Word: année, True Label: 3, Predicted Label: 1
# Word: suivante, True Label: 1, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: les, True Label: 1, Predicted Label: 1
# Word: accords, True Label: 1, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: Genève, True Label: 4, Predicted Label: 1
# Word: étaient, True Label: 1, Predicted Label: 1
# Word: signés, True Label: 1, Predicted Label: 1
# Word: et, True Label: 1, Predicted Label: 1
# Word: l', True Label: 1, Predicted Label: 1
# Word: Indochine, True Label: 1, Predicted Label: 1
# Word: française, True Label: 1, Predicted Label: 1
# Word: avait, True Label: 1, Predicted Label: 1
# Word: vécu, True Label: 1, Predicted Label: 1
# Word: ., True Label: 1, Predicted Label: 1
# Word: Épilogue, True Label: 3, Predicted Label: 1
# Word: L', True Label: 1, Predicted Label: 1
# Word: aventure, True Label: 2, Predicted Label: 1
# Word: coloniale, True Label: 1, Predicted Label: 1
# Word: n', True Label: 1, Predicted Label: 1
# Word: a, True Label: 1, Predicted Label: 1
# Word: été, True Label: 1, Predicted Label: 1
# Word: profitable, True Label: 1, Predicted Label: 1
# Word: que, True Label: 1, Predicted Label: 1
# Word: pour, True Label: 1, Predicted Label: 1
# Word: quelques, True Label: 1, Predicted Label: 1
# Word: grandes, True Label: 1, Predicted Label: 1
# Word: compagnies, True Label: 4, Predicted Label: 1
# Word: privées, True Label: 1, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: comme, True Label: 1, Predicted Label: 1
# Word: la, True Label: 1, Predicted Label: 1
# Word: Banque, True Label: 1, Predicted Label: 1
# Word: d', True Label: 1, Predicted Label: 1
# Word: Indochine, True Label: 4, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: Descours, True Label: 1, Predicted Label: 1
# Word: &, True Label: 1, Predicted Label: 1
# Word: Cabaud, True Label: 1, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: les, True Label: 1, Predicted Label: 1
# Word: Brasseries, True Label: 1, Predicted Label: 1
# Word: et, True Label: 1, Predicted Label: 1
# Word: glacières, True Label: 5, Predicted Label: 1
# Word: d', True Label: 1, Predicted Label: 1
# Word: Indochine, True Label: 4, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: etc, True Label: 1, Predicted Label: 1
# Word: ., True Label: 1, Predicted Label: 1
# Word: Les, True Label: 1, Predicted Label: 1
# Word: banquiers, True Label: 0, Predicted Label: 1
# Word: n', True Label: 1, Predicted Label: 1
# Word: ont, True Label: 1, Predicted Label: 1
# Word: jamais, True Label: 1, Predicted Label: 1
# Word: été, True Label: 1, Predicted Label: 1
# Word: arrêtés, True Label: 1, Predicted Label: 1
# Word: ni, True Label: 1, Predicted Label: 1
# Word: jugés, True Label: 1, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: à, True Label: 1, Predicted Label: 1
# Word: l', True Label: 1, Predicted Label: 1
# Word: exception, True Label: 1, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: la, True Label: 1, Predicted Label: 1
# Word: Chartered, True Label: 1, Predicted Label: 1
# Word: Bank, True Label: 1, Predicted Label: 1
# Word: qui, True Label: 1, Predicted Label: 1
# Word: fut, True Label: 1, Predicted Label: 1
# Word: inculpée, True Label: 1, Predicted Label: 1
# Word: pour, True Label: 1, Predicted Label: 1
# Word: des, True Label: 1, Predicted Label: 1
# Word: pratiques, True Label: 2, Predicted Label: 1
# Word: nettement, True Label: 1, Predicted Label: 1
# Word: frauduleuses, True Label: 1, Predicted Label: 1
# Word: ., True Label: 1, Predicted Label: 1
# Word: Le, True Label: 1, Predicted Label: 1
# Word: ", True Label: 1, Predicted Label: 1
# Word: scandale, True Label: 16, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: les, True Label: 1, Predicted Label: 1
# Word: piastres, True Label: 14, Predicted Label: 1
# Word: ", True Label: 1, Predicted Label: 1
# Word: fut, True Label: 1, Predicted Label: 1
# Word: ramené, True Label: 1, Predicted Label: 1
# Word: à, True Label: 1, Predicted Label: 1
# Word: l', True Label: 1, Predicted Label: 1
# Word: état, True Label: 7, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: détail, True Label: 8, Predicted Label: 1
# Word: exotique, True Label: 1, Predicted Label: 1
# Word: et, True Label: 1, Predicted Label: 1
# Word: insignifiant, True Label: 1, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: indigne, True Label: 1, Predicted Label: 1
# Word: d', True Label: 1, Predicted Label: 1
# Word: être, True Label: 1, Predicted Label: 1
# Word: mentionné, True Label: 1, Predicted Label: 1
# Word: dans, True Label: 1, Predicted Label: 1
# Word: les, True Label: 1, Predicted Label: 1
# Word: manuels, True Label: 8, Predicted Label: 1
# Word: d', True Label: 1, Predicted Label: 1
# Word: histoire, True Label: 8, Predicted Label: 1
# Word: ., True Label: 1, Predicted Label: 1
# Word: Références, True Label: 8, Predicted Label: 1
# Word: bibliographiques, True Label: 1, Predicted Label: 1
# Word: -, True Label: 1, Predicted Label: 1
# Word: Lucien, True Label: 1, Predicted Label: 1
# Word: Bodard, True Label: 1, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: ", True Label: 1, Predicted Label: 1
# Word: La, True Label: 1, Predicted Label: 1
# Word: guerre, True Label: 2, Predicted Label: 1
# Word: d', True Label: 1, Predicted Label: 1
# Word: Indochine, True Label: 4, Predicted Label: 1
# Word: :, True Label: 1, Predicted Label: 1
# Word: L', True Label: 1, Predicted Label: 1
# Word: enlisement, True Label: 16, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: l', True Label: 1, Predicted Label: 1
# Word: humiliation, True Label: 9, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: l', True Label: 1, Predicted Label: 1
# Word: aventure, True Label: 2, Predicted Label: 1
# Word: ", True Label: 1, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: Grasset, True Label: 4, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: 1 500, True Label: 1, Predicted Label: 1
# Word: p., True Label: 5, Predicted Label: 1
# Word: Paris, True Label: 4, Predicted Label: 1
# Word: 1997, True Label: 3, Predicted Label: 1
# Word: ., True Label: 1, Predicted Label: 1
# Word: -, True Label: 1, Predicted Label: 1
# Word: Paul, True Label: 1, Predicted Label: 1
# Word: Mus, True Label: 1, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: Viêtnam, True Label: 4, Predicted Label: 1
# Word: :, True Label: 1, Predicted Label: 1
# Word: Sociologie, True Label: 8, Predicted Label: 1
# Word: d', True Label: 1, Predicted Label: 1
# Word: une, True Label: 1, Predicted Label: 1
# Word: guerre, True Label: 2, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: Seuil, True Label: 4, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: Paris, True Label: 4, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: 1952, True Label: 3, Predicted Label: 1
# Word: ., True Label: 1, Predicted Label: 1
# Word: -, True Label: 1, Predicted Label: 1
# Word: Thanh, True Label: 1, Predicted Label: 1
# Word: H., True Label: 1, Predicted Label: 1
# Word: Vuong, True Label: 1, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: Théorie, True Label: 8, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: les, True Label: 1, Predicted Label: 1
# Word: contextes, True Label: 7, Predicted Label: 1
# Word: et, True Label: 1, Predicted Label: 1
# Word: relations, True Label: 22, Predicted Label: 1
# Word: internationales, True Label: 1, Predicted Label: 1
# Word: :, True Label: 1, Predicted Label: 1
# Word: départ, True Label: 16, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: la, True Label: 1, Predicted Label: 1
# Word: première, True Label: 1, Predicted Label: 1
# Word: Guerre, True Label: 2, Predicted Label: 1
# Word: d', True Label: 1, Predicted Label: 1
# Word: Indochine, True Label: 4, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: dans, True Label: 1, Predicted Label: 1
# Word: Études, True Label: 1, Predicted Label: 1
# Word: Internationales, True Label: 1, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: Vol., True Label: 8, Predicted Label: 1
# Word: XVII, True Label: 1, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: No., True Label: 13, Predicted Label: 1
# Word: 3, True Label: 1, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: pp., True Label: 5, Predicted Label: 1
# Word: 571-597, True Label: 1, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: septembre, True Label: 3, Predicted Label: 1
# Word: 1986, True Label: 3, Predicted Label: 1
# Word: -, True Label: 1, Predicted Label: 1
# Word: Thanh, True Label: 1, Predicted Label: 1
# Word: H., True Label: 1, Predicted Label: 1
# Word: Vuong, True Label: 1, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: colonisations, True Label: 2, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: le, True Label: 1, Predicted Label: 1
# Word: Viêtnam, True Label: 4, Predicted Label: 1
# Word: et, True Label: 1, Predicted Label: 1
# Word: colonialisme, True Label: 8, Predicted Label: 1
# Word: vietnamien, True Label: 1, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: dans, True Label: 1, Predicted Label: 1
# Word: Études, True Label: 1, Predicted Label: 1
# Word: Internationales, True Label: 1, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: Vol., True Label: 8, Predicted Label: 1
# Word: XVIII, True Label: 1, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: No., True Label: 13, Predicted Label: 1
# Word: 3, True Label: 1, Predicted Label: 1
# Word: pp., True Label: 5, Predicted Label: 1
# Word: 546-571, True Label: 1, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: septembre, True Label: 3, Predicted Label: 1
# Word: 1987, True Label: 3, Predicted Label: 1
# Word: ., True Label: 1, Predicted Label: 1
# Word: -, True Label: 1, Predicted Label: 1
# Word: Despuech, True Label: 1, Predicted Label: 1
# Word: Jacques, True Label: 1, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: Le, True Label: 1, Predicted Label: 1
# Word: trafic, True Label: 1, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: les, True Label: 1, Predicted Label: 1
# Word: piastres, True Label: 1, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: Deux, True Label: 1, Predicted Label: 1
# Word: rives, True Label: 6, Predicted Label: 1
# Word: ,, True Label: 1, Predicted Label: 1
# Word: 1953, True Label: 3, Predicted Label: 1
# Word: -, True Label: 1, Predicted Label: 1
# Word: Indochine, True Label: 1, Predicted Label: 1
# Word: française, True Label: 1, Predicted Label: 1
# Word: -, True Label: 1, Predicted Label: 1
# Word: Guerre, True Label: 1, Predicted Label: 1
# Word: d', True Label: 1, Predicted Label: 1
# Word: Indochine, True Label: 4, Predicted Label: 1
# Word: Liens, True Label: 21, Predicted Label: 1
# Word: externes, True Label: 1, Predicted Label: 1
# Word: -, True Label: 1, Predicted Label: 1
# Word: Guerre, True Label: 1, Predicted Label: 1
# Word: d', True Label: 1, Predicted Label: 1
# Word: Indochine, True Label: 4, Predicted Label: 1
# Word: -, True Label: 1, Predicted Label: 1
# Word: dernier, True Label: 1, Predicted Label: 1
# Word: résumé, True Label: 8, Predicted Label: 1
# Word: :, True Label: 1, Predicted Label: 1
# Word: l', True Label: 1, Predicted Label: 1
# Word: ", True Label: 1, Predicted Label: 1
# Word: Affaire, True Label: 16, Predicted Label: 1
# Word: de, True Label: 1, Predicted Label: 1
# Word: les, True Label: 1, Predicted Label: 1
# Word: piastres, True Label: 14, Predicted Label: 1
# Word: ", True Label: 1, Predicted Label: 1
# Word: Catégories, True Label: 8, Predicted Label: 1
# Word: :, True Label: 1, Predicted Label: 1
# Word: Guerre, True Label: 1, Predicted Label: 1
# Word: d', True Label: 1, Predicted Label: 1
# Word: Indochine, True Label: 4, Predicted Label: 1
# Word: ., True Label: 1, Predicted Label: 1
# Word: Affaire, True Label: 16, Predicted Label: 1
# Word: politico-financière, True Label: 1, Predicted Label: 1
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      1580
#            1       0.79      1.00      0.88     38532
#            2       0.00      0.00      0.00      1385
#            3       0.00      0.00      0.00       986
#            4       0.00      0.00      0.00      1286
#            5       0.00      0.00      0.00       416
#            6       0.00      0.00      0.00       123
#            7       0.00      0.00      0.00       415
#            8       0.00      0.00      0.00      1021
#            9       0.00      0.00      0.00       110
#           10       0.00      0.00      0.00         9
#           11       0.00      0.00      0.00       674
#           12       0.00      0.00      0.00        42
#           13       0.00      0.00      0.00       389
#           14       0.00      0.00      0.00       316
#           15       0.00      0.00      0.00       458
#           16       0.00      0.00      0.00       552
#           17       0.00      0.00      0.00        43
#           18       0.00      0.00      0.00        22
#           19       0.00      0.00      0.00        15
#           20       0.00      0.00      0.00        60
#           21       0.00      0.00      0.00        37
#           22       0.00      0.00      0.00        32
#           23       0.00      0.00      0.00       146
#           24       0.00      0.00      0.00         6
#
#     accuracy                           0.79     48655
#    macro avg       0.03      0.04      0.04     48655
# weighted avg       0.63      0.79      0.70     48655
